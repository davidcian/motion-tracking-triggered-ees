# %%
# !py rt-pose-estimation-video.py
# Out:
# Left wrist coordinates: (375.40294647216797, 342.3386478424072)
# Left wrist coordinates: (376.9654846191406, 338.86284828186035)
# Left wrist coordinates: (377.3289489746094, 331.62428855895996)
# Left wrist coordinates: (356.1705780029297, 333.1977939605713)
# Left wrist coordinates: (357.9373550415039, 317.67605781555176)
# Left wrist coordinates: (347.05772399902344, 306.2743091583252)
# Left wrist coordinates: (345.9384536743164, 291.1775779724121)
# Left wrist coordinates: (331.0851287841797, 279.0351963043213)
# Left wrist coordinates: (323.42777252197266, 271.1257266998291)
# Left wrist coordinates: (319.2765808105469, 250.32154083251953)
# Left wrist coordinates: (314.09576416015625, 238.35986137390137)
# Left wrist coordinates: (301.6292953491211, 230.7322883605957)
# Left wrist coordinates: (298.89001846313477, 203.26177597045898)
# Left wrist coordinates: (290.53314208984375, 178.14003467559814)
# Left wrist coordinates: (293.13100814819336, 175.1515245437622)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = './output/Landmarks_coordinates_cam1_911222060374_record_30_09_2021_1404_05.csv'

df_landmarks = pd.read_csv(path,header=None,names=['Frame','Landmarks','x','y','z','depth_z'])

# %%
df_landmarks
# Out:
#       Frame  Landmarks           x           y         z  depth_z
# 0       0.0       15.0  450.181427  176.803050 -0.510525   1329.0
# 1       0.0       13.0  461.996155  188.286710 -0.391427   1320.0
# 2       0.0       11.0  449.849052  134.822559 -0.291396   1350.0
# 3       0.0       16.0  412.570724  249.557333 -0.316854   1422.0
# 4       0.0       14.0  416.638756  213.190985 -0.188134   1401.0
# ...     ...        ...         ...         ...       ...      ...
# 1051  175.0       13.0  461.996841   47.998642 -0.007610      0.0
# 1052  175.0       11.0  487.947159  144.330654  0.049826      0.0
# 1053  175.0       16.0  352.080154  342.257853  0.247866   1547.0
# 1054  175.0       14.0  402.078781  289.993143  0.531106   1476.0
# 1055  175.0       12.0  431.202927  195.807109  0.477531   1449.0
#
# [1056 rows x 6 columns]

# %%
df_landmarks.describe()
# Out:
#              Frame    Landmarks            x            y            z  \
# count  1056.000000  1056.000000  1056.000000  1056.000000  1056.000000
# mean     87.500000    13.500000   390.169640   228.664399     0.162519
# std      50.830077     1.708634    60.180854    72.445219     0.311101
# min       0.000000    11.000000   173.388939   -13.716964    -0.535841
# 25%      43.750000    12.000000   361.482878   178.150381    -0.124271
# 50%      87.500000    13.500000   395.432072   233.403103     0.110040
# 75%     131.250000    15.000000   427.762871   284.596624     0.475882
# max     175.000000    16.000000   529.102058   353.591394     0.824238
#
#            depth_z
# count  1056.000000
# mean   1467.340909
# std     617.550028
# min       0.000000
# 25%    1324.500000
# 50%    1457.000000
# 75%    1547.000000
# max    5004.000000

# %%
df_landmarks.Landmarks.unique()
# Out:
# array([15., 13., 11., 16., 14., 12.])

# %%
df_landmarks[df_landmarks.depth_z == 0].describe()
# Out:
#             Frame  Landmarks           x           y          z  depth_z
# count   64.000000  64.000000   64.000000   64.000000  64.000000     64.0
# mean    88.312500  13.109375  401.941760  217.994922   0.016481      0.0
# std     52.633466   1.663017   86.448189   64.921476   0.240074      0.0
# min      4.000000  11.000000  183.985157   47.998642  -0.300421      0.0
# 25%     48.250000  11.000000  362.618790  161.396813  -0.166312      0.0
# 50%     85.500000  13.000000  400.366707  239.386504  -0.050493      0.0
# 75%    136.250000  14.250000  478.919430  263.163779   0.083137      0.0
# max    175.000000  16.000000  527.987747  332.991743   0.637181      0.0

# %%
df_landmarks[df_landmarks.depth_z != 0].describe()
# Out:
#             Frame   Landmarks           x           y           z      depth_z
# count  992.000000  992.000000  992.000000  992.000000  992.000000   992.000000
# mean    87.447581   13.525202  389.410149  229.352752    0.171941  1562.008065
# std     50.738514    1.709288   58.060409   72.879917    0.312897   507.914541
# min      0.000000   11.000000  173.388939  -13.716964   -0.535841  1063.000000
# 25%     43.000000   12.000000  361.482878  178.615465   -0.120888  1356.500000
# 50%     87.500000   14.000000  395.305157  232.516837    0.195527  1465.000000
# 75%    131.000000   15.000000  425.018187  286.199362    0.479528  1551.000000
# max    175.000000   16.000000  529.102058  353.591394    0.824238  5004.000000
